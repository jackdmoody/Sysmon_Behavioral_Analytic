# %% [markdown]
# # Sysmon Pipeline Runner\n\nThis notebook is intentionally slim. All logic lives in `sysmon_pipeline/`.

# %%
import pandas as pd
from sysmon_pipeline import SysmonConfig, SysmonPipeline

# %%
# TODO: point to your Sysmon export (csv/xlsx/parquet)
# df = pd.read_csv("sysmon.csv")
# For xlsx, use: pd.read_excel("sysmon.xlsx")

# %%
cfg = SysmonConfig(
    window_seconds=60,
    iforest_contamination=0.02,
    cache_dir=None,
    debug=False,
)

pipe = SysmonPipeline(cfg)

# For now we fit and score on the same df; ideally fit on a baseline period.
# pipe.fit(df_baseline)
# artifacts = pipe.score(df_new)

# Example:
# pipe.fit(df)
# artifacts = pipe.score(df)

# %%
# display(artifacts.triage.head(20))
